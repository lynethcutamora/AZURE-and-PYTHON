# %%
var_num=25

if var_num>30:
    print ("is greater than 30: "+str(var_num>30))
else:
    print ("is smaller than 30: "+str(var_num<30))
# Out:
# is smaller than 30: True

# %%
for i in range(x):
    print (i)


even_number={x for x in range(10) if x%2==0}
print (even_number)

squares_num={x: x*x for x in range(10)}
print(squares_num)
# Out:
# 0
# 1
# 2
# 3
# 4
# {0, 2, 4, 6, 8}
# {0: 0, 1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81}

# %%
x=2

while x>0:
  print (x)
  x-=1
# Out:
# 2
# 1

# %%
#manipulating string

new_str='Hello Future'
message=new_str.replace('Hello','Hi')
print (message)

msg_trim='     Hello Future     '
print(msg_trim.strip())

index=new_str.find("Future")
print(index)

template='hello {}'
print(template.format('Lyneth'))

ls=new_str.split()
print(ls)
# Out:
# Hi Future
# Hello Future
# 6
# hello Lyneth
# ['Hello', 'Future']

# %%
# Python code​​​​​​‌‌​‌‌‌‌​‌‌​‌​‌​​​​​​​‌​‌​ below
# Use print("messages...") to debug your solution.

show_expected_result = False
show_hints = False

def reverse_string(text):
    # Your code goes here.
    res=text[::-1]
    return res

def reverse_string_for(x):
    res=""
    for char in x:
        res=char+res
    return res

try:
    text=reverse_string("Hello Future")
    print(text)
    text2=reverse_string_for("Python")
    print(text2)
except Exception as e:
    print("Error: ", e)
# Out:
# erutuF olleH
# nohtyP
